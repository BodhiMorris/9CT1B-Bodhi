# %%
# List Operations Activity
# Create a list of favourite fruits
favourite_fruits = ['apple', 'banana', 'orange']

# TODO: Add a new fruit to the list and print the result.
favourite_fruits.append('mango')
print(favourite_fruits)

# TODO: Remove a fruit from the list and print the result.
favourite_fruits[2:] = []
print(favourite_fruits)

# TODO: Change the order of fruits and print the result.
favourite_fruits.append('orange')
favourite_fruits[1] = ('apple')
favourite_fruits[0] = ('banana')
print(favourite_fruits)

# TODO: Access the second fruit in the list by index and print the result.
print(favourite_fruits[1])
# Out:
# ['apple', 'banana', 'orange', 'mango']
# ['apple', 'banana']
# ['banana', 'apple', 'orange']
# apple

# %%
# Custom List Manipulation Activity
#TODO: Create a list of favourite hobbies or activities
favourite_hobbies = ['bass', 'sekiro', 'youtube']

# TODO: Add a new hobby to the list and print the result
favourite_hobbies.append('elden ring')
print(favourite_hobbies)

# TODO: Remove an existing hobby from the list and print the result
favourite_hobbies[3:] = []
print(favourite_hobbies)

# TODO: Change the order of hobbies and print the result
favourite_hobbies = ['sekiro', 'bass', 'youtube']
print(favourite_hobbies)

# TODO: Update a specific hobby with a new one and print the result
favourite_hobbies[2] = ('dog time')
print(favourite_hobbies)
# Out:
# ['bass', 'sekiro', 'youtube', 'elden ring']
# ['bass', 'sekiro', 'youtube']
# ['sekiro', 'bass', 'youtube']
# ['sekiro', 'bass', 'dog time']

# %%
# Student Grades List Activity without Dictionaries
# Create lists for student names and grades
student_names = ['Alice', 'Bob', 'Charlie', 'David', 'Emily']
student_grades = [85, 92, 78, 88, 95]

#TODO: Add a new student and their grade to the lists
student_names.append('Frank')
student_grades.append(43)

#TODO: Print the original lists
print(student_names[:5], student_grades[:5])

#TODO: Remove the third student and their grade from the list
student_names.pop(2)
student_grades.pop(2)

#TODO: Print the updated lists after removal
print(student_names, student_grades)

#TODO: Update the grade of a specific student
student_grades[3] = 98

#TODO: Calculate and print the average grade of all students
print(sum(student_grades)/len(student_grades))
# Out:
# ['Alice', 'Bob', 'Charlie', 'David', 'Emily'] [85, 92, 78, 88, 95]
# ['Alice', 'Bob', 'David', 'Emily', 'Frank'] [85, 92, 88, 95, 43]
# 81.2

# %%
# Define the dimensions of the grid
rows = 3
cols = 4

# Create a grid using a list of lists
grid = [['-' for _ in range(cols)] for _ in range(rows)]

# Print the grid
for row in grid:
    print(' '.join(row))
# Out:
# - - - -
# - - - -
# - - - -

# %%
# Define the dimensions of the grid
rows = 3
cols = 3

# Create a grid using a list of lists
grid = [['-' for _ in range(cols)] for _ in range(rows)]

# Initial position of 'X'
x_row = 2
x_col = 2
grid[x_row][x_col] = 'X'

# Print the grid
def print_grid():
    for row in grid:
        print(' '.join(row))

# Print the initial grid with 'X'
print("Initial Grid:")
print_grid()

# Movement function
def move_x(direction):
    global x_row, x_col
    grid[x_row][x_col] = '-'  # Clear current position

    # Update position based on direction
    if direction == 'left' and x_col > 0:
        x_col -= 1
    elif direction == 'right' and x_col < cols - 1:
        x_col += 1
    elif direction == 'up' and x_row > 0:
        x_row -= 1
    elif direction == 'down' and x_row < rows - 1:
        x_row += 1

    grid[x_row][x_col] = 'X'  # Set new position
    print("\nAfter Move:")
    print_grid()

# Allow user to choose direction and move 'X'
while True:
    direction = input("\nEnter direction (left/right/up/down) or 'exit' to quit: ").lower()
    if direction == 'exit':
        break
    elif direction in ['left', 'right', 'up', 'down']:
        move_x(direction)
    else:
        print("Invalid direction! Please enter left/right/up/down or 'exit'.")
# Out:
# Initial Grid:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - X
# - - -
#
# After Move:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - X
# - - -
#
# After Move:
# - - -
# - X -
# - - -
#
# After Move:
# - X -
# - - -
# - - -
#
# After Move:
# - X -
# - - -
# - - -
# Invalid direction! Please enter left/right/up/down or 'exit'.

# %%
# Define the dimensions of the grid
rows = 3
cols = 3

# Create a grid using a list of lists
grid = [['-' for _ in range(cols)] for _ in range(rows)]

# Initial position of 'X'
x_row = 2
x_col = 2
grid[x_row][x_col] = 'X'

# Print the grid
def print_grid():
    for row in grid:
        print(' '.join(row))

# Print the initial grid with 'X'
print("Initial Grid:")
print_grid()

# Movement function
def move_x(direction):
    global x_row, x_col
    grid[x_row][x_col] = '*'  # Clear current position

    # Update position based on direction
    if direction == 'left' and x_col > 0:
        x_col -= 1
    elif direction == 'right' and x_col < cols - 1:
        x_col += 1
    elif direction == 'up' and x_row > 0:
        x_row -= 1
    elif direction == 'down' and x_row < rows - 1:
        x_row += 1

    grid[x_row][x_col] = 'X'  # Set new position
    print("\nAfter Move:")
    print_grid()

# Allow user to choose direction and move 'X'
while True:
    direction = input("\nEnter direction (left/right/up/down) or 'exit' to quit: ").lower()
    if direction == 'exit':
        break
    elif direction in ['left', 'right', 'up', 'down']:
        move_x(direction)
    else:
        print("Invalid direction! Please enter left/right/up/down or 'exit'.")
# Out:
# Initial Grid:
# - - -
# - - -
# - - X
#
# After Move:
# - - -
# - - X
# - - -
#
# After Move:
# - - X
# - - -
# - - -
#
# After Move:
# - - -
# - - X
# - - -
#
# After Move:
# - - -
# - X -
# - - -
# Invalid direction! Please enter left/right/up/down or 'exit'.
# Invalid direction! Please enter left/right/up/down or 'exit'.
# Invalid direction! Please enter left/right/up/down or 'exit'.
# Invalid direction! Please enter left/right/up/down or 'exit'.
# Invalid direction! Please enter left/right/up/down or 'exit'.
# Invalid direction! Please enter left/right/up/down or 'exit'.
